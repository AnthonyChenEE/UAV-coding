# %% [markdown]
# <a href="https://colab.research.google.com/github/AnthonyChenEE/UAV_coding/blob/main/UAV_coding_note_Yuanzhe_(Anthony)_Chen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rng('default'); map = mapClutter;
planner = plannerAStarGrid(map);
start = [2 3]; goal = [248 248]
plan(planner, start, goal)
show(planner)
# Out:
#   File "/tmp/ipython-input-3637455901.py", line 3
#     start = [2 3]; goal = [248 248]
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
